# %% [markdown]
# <a href="https://colab.research.google.com/github/hariboinmypocket/BioMapAI/blob/main/af/examples/peptide_binder_design.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # AfDesign - peptide binder design
# For a given protein target and protein binder length, generate/hallucinate a protein binder sequence AlphaFold thinks will bind to the target structure. To do this, we maximize number of contacts at the interface and maximize pLDDT of the binder.
#
# **WARNING**
# 1.   This notebook is in active development and was designed for demonstration purposes only.
# 2.   Using AfDesign as the only "loss" function for design might be a bad idea, you may find adversarial sequences (aka. sequences that trick AlphaFold).

# %%
#@title **setup**
import os
if not os.path.isdir("params"):
  # get code
  os.system("pip -q install git+https://github.com/sokrypton/ColabDesign.git@v1.1.1")
  # for debugging
  os.system("ln -s /usr/local/lib/python3.*/dist-packages/colabdesign colabdesign")
  # download params
  os.system("mkdir params")
  os.system("apt-get install aria2 -qq")
  os.system("aria2c -q -x 16 https://storage.googleapis.com/alphafold/alphafold_params_2022-12-06.tar")
  os.system("tar -xf alphafold_params_2022-12-06.tar -C params")

import warnings
warnings.simplefilter(action='ignore', category=FutureWarning)

import os
from colabdesign import mk_afdesign_model, clear_mem
from colabdesign.shared.utils import copy_dict
from colabdesign.af.alphafold.common import residue_constants

from IPython.display import HTML
from google.colab import files
import numpy as np

#########################
def get_pdb(pdb_code=""):
  if pdb_code is None or pdb_code == "":
    upload_dict = files.upload()
    pdb_string = upload_dict[list(upload_dict.keys())[0]]
    with open("tmp.pdb","wb") as out: out.write(pdb_string)
    return "tmp.pdb"
  elif os.path.isfile(pdb_code):
    return pdb_code
  elif len(pdb_code) == 4:
    os.system(f"wget -qnc https://files.rcsb.org/view/{pdb_code}.pdb")
    return f"{pdb_code}.pdb"
  else:
    os.system(f"wget -qnc https://alphafold.ebi.ac.uk/files/AF-{pdb_code}-F1-model_v3.pdb")
    return f"AF-{pdb_code}-F1-model_v3.pdb"

# %%
#@title **prep inputs**
import re
#@markdown ---
#@markdown **target info**
pdb = "4N5T" #@param {type:"string"}
#@markdown - enter PDB code or UniProt code (to fetch AlphaFoldDB model) or leave blink to upload your own
target_chain = "A" #@param {type:"string"}
target_hotspot = "" #@param {type:"string"}
if target_hotspot == "": target_hotspot = None
#@markdown - restrict loss to predefined positions on target (eg. "1-10,12,15")
target_flexible = False #@param {type:"boolean"}
#@markdown - allow backbone of target structure to be flexible

#@markdown ---
#@markdown **binder info**
binder_len = 14 #@param {type:"integer"}
#@markdown - length of binder to hallucination
binder_seq = "" #@param {type:"string"}
binder_seq = re.sub("[^A-Z]", "", binder_seq.upper())
if len(binder_seq) > 0:
  binder_len = len(binder_seq)
else:
  binder_seq = None
#@markdown - if defined, will initialize design with this sequence

binder_chain = "" #@param {type:"string"}
if binder_chain == "": binder_chain = None
#@markdown - if defined, supervised loss is used (binder_len is ignored)

#@markdown ---
#@markdown **model config**
use_multimer = False #@param {type:"boolean"}
#@markdown - use alphafold-multimer for design
num_recycles = 0 #@param ["0", "1", "3", "6"] {type:"raw"}
num_models = "2" #@param ["1", "2", "3", "4", "5", "all"]
num_models = 5 if num_models == "all" else int(num_models)
#@markdown - number of trained models to use during optimization


x = {"pdb_filename":pdb,
     "chain":target_chain,
     "binder_len":binder_len,
     "binder_chain":binder_chain,
     "hotspot":target_hotspot,
     "use_multimer":use_multimer,
     "rm_target_seq":target_flexible}

x["pdb_filename"] = get_pdb(x["pdb_filename"])

if "x_prev" not in dir() or x != x_prev:
  clear_mem()
  model = mk_afdesign_model(protocol="binder",
                            use_multimer=x["use_multimer"],
                            num_recycles=num_recycles,
                            recycle_mode="sample")
  model.prep_inputs(**x,
                    ignore_missing=False)
  x_prev = copy_dict(x)
  print("target length:", model._target_len)
  print("binder length:", model._binder_len)
  binder_len = model._binder_len
# Out:
# target length: 90
# binder length: 14

# %%
#@title **run AfDesign**
from scipy.special import softmax

optimizer = "pssm_semigreedy" #@param ["pssm_semigreedy", "3stage", "semigreedy", "pssm", "logits", "soft", "hard"]
#@markdown - `pssm_semigreedy` - uses the designed PSSM to bias semigreedy opt. (Recommended)
#@markdown - `3stage` - gradient based optimization (GD) (logits → soft → hard)
#@markdown - `pssm` - GD optimize (logits → soft) to get a sequence profile (PSSM).
#@markdown - `semigreedy` - tries X random mutations, accepts those that decrease loss
#@markdown - `logits` - GD optimize logits inputs (continious)
#@markdown - `soft` - GD optimize softmax(logits) inputs (probabilities)
#@markdown - `hard` - GD optimize one_hot(logits) inputs (discrete)

#@markdown WARNING: The output sequence from `pssm`,`logits`,`soft` is not one_hot. To get a valid sequence use the other optimizers, or redesign the output backbone with another protocol like ProteinMPNN.

#@markdown ----
#@markdown #### advanced GD settings
GD_method = "sgd" #@param ["adabelief", "adafactor", "adagrad", "adam", "adamw", "fromage", "lamb", "lars", "noisy_sgd", "dpsgd", "radam", "rmsprop", "sgd", "sm3", "yogi"]
learning_rate = 0.1 #@param {type:"raw"}
norm_seq_grad = True #@param {type:"boolean"}
dropout = True #@param {type:"boolean"}

model.restart(seq=binder_seq)
model.set_optimizer(optimizer=GD_method,
                    learning_rate=learning_rate,
                    norm_seq_grad=norm_seq_grad)
models = model._model_names[:num_models]

flags = {"num_recycles":num_recycles,
         "models":models,
         "dropout":dropout}

if optimizer == "3stage":
  model.design_3stage(120, 60, 10, **flags)
  pssm = softmax(model._tmp["seq_logits"],-1)

if optimizer == "pssm_semigreedy":
  model.design_pssm_semigreedy(120, 32, **flags)
  pssm = softmax(model._tmp["seq_logits"],1)

if optimizer == "semigreedy":
  model.design_pssm_semigreedy(0, 32, **flags)
  pssm = None

if optimizer == "pssm":
  model.design_logits(120, e_soft=1.0, num_models=1, ramp_recycles=True, **flags)
  model.design_soft(32, num_models=1, **flags)
  flags.update({"dropout":False,"save_best":True})
  model.design_soft(10, num_models=num_models, **flags)
  pssm = softmax(model.aux["seq"]["logits"],-1)

O = {"logits":model.design_logits,
     "soft":model.design_soft,
     "hard":model.design_hard}

if optimizer in O:
  O[optimizer](120, num_models=1, ramp_recycles=True, **flags)
  flags.update({"dropout":False,"save_best":True})
  O[optimizer](10, num_models=num_models, **flags)
  pssm = softmax(model.aux["seq"]["logits"],-1)

model.save_pdb(f"{model.protocol}.pdb")
# Out:
# Stage 1: running (logits → soft)
# 1 models [0] recycles 0 hard 0 soft 0.01 temp 1 loss 5.24 i_con 5.20 plddt 0.58 ptm 0.72 i_ptm 0.05
# 2 models [1] recycles 0 hard 0 soft 0.02 temp 1 loss 6.79 i_con 6.75 plddt 0.63 ptm 0.77 i_ptm 0.03
# 3 models [1] recycles 0 hard 0 soft 0.03 temp 1 loss 6.36 i_con 6.32 plddt 0.60 ptm 0.76 i_ptm 0.04
# 4 models [1] recycles 0 hard 0 soft 0.03 temp 1 loss 5.69 i_con 5.64 plddt 0.54 ptm 0.76 i_ptm 0.05
# 5 models [0] recycles 0 hard 0 soft 0.04 temp 1 loss 4.67 i_con 4.62 plddt 0.49 ptm 0.72 i_ptm 0.12
# 6 models [1] recycles 0 hard 0 soft 0.05 temp 1 loss 5.45 i_con 5.40 plddt 0.56 ptm 0.76 i_ptm 0.04
# 7 models [1] recycles 0 hard 0 soft 0.06 temp 1 loss 4.37 i_con 4.32 plddt 0.46 ptm 0.75 i_ptm 0.05
# 8 models [0] recycles 0 hard 0 soft 0.07 temp 1 loss 3.77 i_con 3.71 plddt 0.45 ptm 0.73 i_ptm 0.19
# 9 models [0] recycles 0 hard 0 soft 0.07 temp 1 loss 3.69 i_con 3.64 plddt 0.46 ptm 0.73 i_ptm 0.24
# 10 models [0] recycles 0 hard 0 soft 0.08 temp 1 loss 3.47 i_con 3.43 plddt 0.54 ptm 0.74 i_ptm 0.34
# 11 models [1] recycles 0 hard 0 soft 0.09 temp 1 loss 4.06 i_con 4.00 plddt 0.45 ptm 0.76 i_ptm 0.14
# 12 models [0] recycles 0 hard 0 soft 0.10 temp 1 loss 3.40 i_con 3.35 plddt 0.56 ptm 0.75 i_ptm 0.36
# 13 models [0] recycles 0 hard 0 soft 0.11 temp 1 loss 3.21 i_con 3.18 plddt 0.62 ptm 0.76 i_ptm 0.45
# 14 models [1] recycles 0 hard 0 soft 0.12 temp 1 loss 3.22 i_con 3.18 plddt 0.59 ptm 0.79 i_ptm 0.42
# 15 models [1] recycles 0 hard 0 soft 0.12 temp 1 loss 3.27 i_con 3.23 plddt 0.59 ptm 0.79 i_ptm 0.37
# 16 models [1] recycles 0 hard 0 soft 0.13 temp 1 loss 3.00 i_con 2.96 plddt 0.64 ptm 0.81 i_ptm 0.51
# 17 models [1] recycles 0 hard 0 soft 0.14 temp 1 loss 2.91 i_con 2.88 plddt 0.67 ptm 0.82 i_ptm 0.53
# 18 models [1] recycles 0 hard 0 soft 0.15 temp 1 loss 2.99 i_con 2.96 plddt 0.66 ptm 0.82 i_ptm 0.54
# 19 models [1] recycles 0 hard 0 soft 0.16 temp 1 loss 2.67 i_con 2.65 plddt 0.74 ptm 0.83 i_ptm 0.62
# 20 models [1] recycles 0 hard 0 soft 0.17 temp 1 loss 2.86 i_con 2.83 plddt 0.70 ptm 0.82 i_ptm 0.55
# 21 models [1] recycles 0 hard 0 soft 0.17 temp 1 loss 2.69 i_con 2.67 plddt 0.74 ptm 0.83 i_ptm 0.60
# 22 models [1] recycles 0 hard 0 soft 0.18 temp 1 loss 2.39 i_con 2.37 plddt 0.79 ptm 0.85 i_ptm 0.69
# 23 models [0] recycles 0 hard 0 soft 0.19 temp 1 loss 2.67 i_con 2.64 plddt 0.75 ptm 0.82 i_ptm 0.63
# 24 models [1] recycles 0 hard 0 soft 0.20 temp 1 loss 2.41 i_con 2.39 plddt 0.80 ptm 0.85 i_ptm 0.69
# 25 models [1] recycles 0 hard 0 soft 0.21 temp 1 loss 2.06 i_con 2.05 plddt 0.86 ptm 0.86 i_ptm 0.76
# 26 models [0] recycles 0 hard 0 soft 0.22 temp 1 loss 2.45 i_con 2.43 plddt 0.80 ptm 0.83 i_ptm 0.68
# 27 models [0] recycles 0 hard 0 soft 0.23 temp 1 loss 2.36 i_con 2.34 plddt 0.83 ptm 0.83 i_ptm 0.70
# 28 models [1] recycles 0 hard 0 soft 0.23 temp 1 loss 2.00 i_con 1.99 plddt 0.88 ptm 0.87 i_ptm 0.79
# 29 models [0] recycles 0 hard 0 soft 0.24 temp 1 loss 2.27 i_con 2.25 plddt 0.84 ptm 0.84 i_ptm 0.73
# 30 models [1] recycles 0 hard 0 soft 0.25 temp 1 loss 2.15 i_con 2.14 plddt 0.84 ptm 0.86 i_ptm 0.76
# 31 models [0] recycles 0 hard 0 soft 0.26 temp 1 loss 2.17 i_con 2.15 plddt 0.86 ptm 0.84 i_ptm 0.75
# 32 models [0] recycles 0 hard 0 soft 0.27 temp 1 loss 2.33 i_con 2.32 plddt 0.83 ptm 0.84 i_ptm 0.72
# 33 models [1] recycles 0 hard 0 soft 0.28 temp 1 loss 2.16 i_con 2.15 plddt 0.85 ptm 0.86 i_ptm 0.74
# 34 models [1] recycles 0 hard 0 soft 0.28 temp 1 loss 2.02 i_con 2.00 plddt 0.86 ptm 0.87 i_ptm 0.78
# 35 models [1] recycles 0 hard 0 soft 0.29 temp 1 loss 1.75 i_con 1.74 plddt 0.91 ptm 0.88 i_ptm 0.83
# 36 models [0] recycles 0 hard 0 soft 0.30 temp 1 loss 2.04 i_con 2.03 plddt 0.87 ptm 0.85 i_ptm 0.77
# 37 models [1] recycles 0 hard 0 soft 0.31 temp 1 loss 1.69 i_con 1.69 plddt 0.92 ptm 0.88 i_ptm 0.84
# 38 models [1] recycles 0 hard 0 soft 0.32 temp 1 loss 1.75 i_con 1.74 plddt 0.91 ptm 0.88 i_ptm 0.82
# 39 models [0] recycles 0 hard 0 soft 0.33 temp 1 loss 2.05 i_con 2.03 plddt 0.87 ptm 0.85 i_ptm 0.77
# 40 models [1] recycles 0 hard 0 soft 0.33 temp 1 loss 1.59 i_con 1.58 plddt 0.94 ptm 0.88 i_ptm 0.85
# 41 models [0] recycles 0 hard 0 soft 0.34 temp 1 loss 2.00 i_con 1.99 plddt 0.88 ptm 0.85 i_ptm 0.78
# 42 models [0] recycles 0 hard 0 soft 0.35 temp 1 loss 1.82 i_con 1.81 plddt 0.91 ptm 0.86 i_ptm 0.81
# 43 models [1] recycles 0 hard 0 soft 0.36 temp 1 loss 1.59 i_con 1.58 plddt 0.93 ptm 0.89 i_ptm 0.84
# 44 models [1] recycles 0 hard 0 soft 0.37 temp 1 loss 1.66 i_con 1.65 plddt 0.93 ptm 0.88 i_ptm 0.83
# 45 models [0] recycles 0 hard 0 soft 0.38 temp 1 loss 1.92 i_con 1.90 plddt 0.89 ptm 0.85 i_ptm 0.79
# 46 models [0] recycles 0 hard 0 soft 0.38 temp 1 loss 1.73 i_con 1.72 plddt 0.92 ptm 0.86 i_ptm 0.82
# 47 models [0] recycles 0 hard 0 soft 0.39 temp 1 loss 1.86 i_con 1.85 plddt 0.90 ptm 0.86 i_ptm 0.80
# 48 models [0] recycles 0 hard 0 soft 0.40 temp 1 loss 1.77 i_con 1.76 plddt 0.92 ptm 0.86 i_ptm 0.82
# 49 models [0] recycles 0 hard 0 soft 0.41 temp 1 loss 1.75 i_con 1.74 plddt 0.92 ptm 0.86 i_ptm 0.82
# 50 models [1] recycles 0 hard 0 soft 0.42 temp 1 loss 1.62 i_con 1.62 plddt 0.93 ptm 0.89 i_ptm 0.84
# 51 models [1] recycles 0 hard 0 soft 0.42 temp 1 loss 1.52 i_con 1.52 plddt 0.94 ptm 0.89 i_ptm 0.86
# 52 models [1] recycles 0 hard 0 soft 0.43 temp 1 loss 1.43 i_con 1.42 plddt 0.95 ptm 0.89 i_ptm 0.86
# 53 models [0] recycles 0 hard 0 soft 0.44 temp 1 loss 1.76 i_con 1.75 plddt 0.92 ptm 0.85 i_ptm 0.81
# 54 models [0] recycles 0 hard 0 soft 0.45 temp 1 loss 1.63 i_con 1.62 plddt 0.93 ptm 0.86 i_ptm 0.83
# 55 models [0] recycles 0 hard 0 soft 0.46 temp 1 loss 1.70 i_con 1.69 plddt 0.93 ptm 0.86 i_ptm 0.82
# 56 models [0] recycles 0 hard 0 soft 0.47 temp 1 loss 1.64 i_con 1.63 plddt 0.93 ptm 0.86 i_ptm 0.84
# 57 models [1] recycles 0 hard 0 soft 0.47 temp 1 loss 1.61 i_con 1.60 plddt 0.93 ptm 0.88 i_ptm 0.85
# 58 models [1] recycles 0 hard 0 soft 0.48 temp 1 loss 1.48 i_con 1.47 plddt 0.94 ptm 0.89 i_ptm 0.86
# 59 models [1] recycles 0 hard 0 soft 0.49 temp 1 loss 1.50 i_con 1.50 plddt 0.94 ptm 0.89 i_ptm 0.86
# 60 models [0] recycles 0 hard 0 soft 0.50 temp 1 loss 1.82 i_con 1.81 plddt 0.90 ptm 0.86 i_ptm 0.81
# 61 models [1] recycles 0 hard 0 soft 0.51 temp 1 loss 1.44 i_con 1.43 plddt 0.95 ptm 0.89 i_ptm 0.87
# 62 models [1] recycles 0 hard 0 soft 0.52 temp 1 loss 1.51 i_con 1.51 plddt 0.94 ptm 0.89 i_ptm 0.85
# 63 models [1] recycles 0 hard 0 soft 0.53 temp 1 loss 1.44 i_con 1.43 plddt 0.95 ptm 0.89 i_ptm 0.86
# 64 models [1] recycles 0 hard 0 soft 0.53 temp 1 loss 1.37 i_con 1.37 plddt 0.96 ptm 0.89 i_ptm 0.87
# 65 models [0] recycles 0 hard 0 soft 0.54 temp 1 loss 1.77 i_con 1.76 plddt 0.91 ptm 0.86 i_ptm 0.81
# 66 models [1] recycles 0 hard 0 soft 0.55 temp 1 loss 1.41 i_con 1.41 plddt 0.95 ptm 0.89 i_ptm 0.87
# 67 models [0] recycles 0 hard 0 soft 0.56 temp 1 loss 1.67 i_con 1.66 plddt 0.93 ptm 0.86 i_ptm 0.83
# 68 models [1] recycles 0 hard 0 soft 0.57 temp 1 loss 1.47 i_con 1.47 plddt 0.94 ptm 0.89 i_ptm 0.86
# 69 models [0] recycles 0 hard 0 soft 0.57 temp 1 loss 1.75 i_con 1.74 plddt 0.92 ptm 0.86 i_ptm 0.82
# 70 models [0] recycles 0 hard 0 soft 0.58 temp 1 loss 1.58 i_con 1.58 plddt 0.93 ptm 0.86 i_ptm 0.84
# 71 models [0] recycles 0 hard 0 soft 0.59 temp 1 loss 1.73 i_con 1.72 plddt 0.92 ptm 0.86 i_ptm 0.82
# 72 models [0] recycles 0 hard 0 soft 0.60 temp 1 loss 1.71 i_con 1.70 plddt 0.93 ptm 0.86 i_ptm 0.82
# 73 models [1] recycles 0 hard 0 soft 0.61 temp 1 loss 1.50 i_con 1.49 plddt 0.95 ptm 0.89 i_ptm 0.86
# 74 models [1] recycles 0 hard 0 soft 0.62 temp 1 loss 1.39 i_con 1.38 plddt 0.95 ptm 0.89 i_ptm 0.87
# 75 models [1] recycles 0 hard 0 soft 0.62 temp 1 loss 1.44 i_con 1.43 plddt 0.95 ptm 0.89 i_ptm 0.86
# 76 models [1] recycles 0 hard 0 soft 0.63 temp 1 loss 1.42 i_con 1.42 plddt 0.96 ptm 0.88 i_ptm 0.86
# 77 models [0] recycles 0 hard 0 soft 0.64 temp 1 loss 1.60 i_con 1.59 plddt 0.93 ptm 0.86 i_ptm 0.84
# 78 models [0] recycles 0 hard 0 soft 0.65 temp 1 loss 1.64 i_con 1.63 plddt 0.93 ptm 0.86 i_ptm 0.83
# 79 models [0] recycles 0 hard 0 soft 0.66 temp 1 loss 1.57 i_con 1.57 plddt 0.93 ptm 0.87 i_ptm 0.84
# 80 models [0] recycles 0 hard 0 soft 0.67 temp 1 loss 1.64 i_con 1.63 plddt 0.93 ptm 0.86 i_ptm 0.84
# 81 models [0] recycles 0 hard 0 soft 0.68 temp 1 loss 1.68 i_con 1.67 plddt 0.93 ptm 0.86 i_ptm 0.82
# 82 models [1] recycles 0 hard 0 soft 0.68 temp 1 loss 1.41 i_con 1.40 plddt 0.95 ptm 0.89 i_ptm 0.86
# 83 models [1] recycles 0 hard 0 soft 0.69 temp 1 loss 1.41 i_con 1.40 plddt 0.95 ptm 0.89 i_ptm 0.87
# 84 models [1] recycles 0 hard 0 soft 0.70 temp 1 loss 1.42 i_con 1.42 plddt 0.95 ptm 0.89 i_ptm 0.87
# 85 models [1] recycles 0 hard 0 soft 0.71 temp 1 loss 1.40 i_con 1.40 plddt 0.95 ptm 0.89 i_ptm 0.87
# 86 models [1] recycles 0 hard 0 soft 0.72 temp 1 loss 1.41 i_con 1.40 plddt 0.95 ptm 0.89 i_ptm 0.86
# 87 models [0] recycles 0 hard 0 soft 0.72 temp 1 loss 1.56 i_con 1.56 plddt 0.93 ptm 0.87 i_ptm 0.83
# 88 models [1] recycles 0 hard 0 soft 0.73 temp 1 loss 1.43 i_con 1.42 plddt 0.95 ptm 0.89 i_ptm 0.86
# 89 models [1] recycles 0 hard 0 soft 0.74 temp 1 loss 1.43 i_con 1.43 plddt 0.95 ptm 0.89 i_ptm 0.86
# 90 models [0] recycles 0 hard 0 soft 0.75 temp 1 loss 1.76 i_con 1.75 plddt 0.92 ptm 0.86 i_ptm 0.80
# 91 models [0] recycles 0 hard 0 soft 0.76 temp 1 loss 1.69 i_con 1.69 plddt 0.92 ptm 0.86 i_ptm 0.82
# 92 models [0] recycles 0 hard 0 soft 0.77 temp 1 loss 1.59 i_con 1.59 plddt 0.94 ptm 0.86 i_ptm 0.84
# 93 models [1] recycles 0 hard 0 soft 0.78 temp 1 loss 1.51 i_con 1.51 plddt 0.95 ptm 0.89 i_ptm 0.86
# 94 models [1] recycles 0 hard 0 soft 0.78 temp 1 loss 1.46 i_con 1.45 plddt 0.95 ptm 0.89 i_ptm 0.86
# 95 models [1] recycles 0 hard 0 soft 0.79 temp 1 loss 1.41 i_con 1.41 plddt 0.95 ptm 0.89 i_ptm 0.87
# 96 models [0] recycles 0 hard 0 soft 0.80 temp 1 loss 1.57 i_con 1.57 plddt 0.94 ptm 0.86 i_ptm 0.84
# 97 models [1] recycles 0 hard 0 soft 0.81 temp 1 loss 1.45 i_con 1.45 plddt 0.95 ptm 0.89 i_ptm 0.87
# 98 models [1] recycles 0 hard 0 soft 0.82 temp 1 loss 1.47 i_con 1.46 plddt 0.94 ptm 0.89 i_ptm 0.85
# 99 models [1] recycles 0 hard 0 soft 0.82 temp 1 loss 1.47 i_con 1.46 plddt 0.95 ptm 0.89 i_ptm 0.86
# 100 models [0] recycles 0 hard 0 soft 0.83 temp 1 loss 1.82 i_con 1.81 plddt 0.91 ptm 0.85 i_ptm 0.81
# 101 models [1] recycles 0 hard 0 soft 0.84 temp 1 loss 1.39 i_con 1.39 plddt 0.96 ptm 0.89 i_ptm 0.87
# 102 models [1] recycles 0 hard 0 soft 0.85 temp 1 loss 1.45 i_con 1.44 plddt 0.95 ptm 0.89 i_ptm 0.86
# 103 models [1] recycles 0 hard 0 soft 0.86 temp 1 loss 1.40 i_con 1.39 plddt 0.95 ptm 0.89 i_ptm 0.87
# 104 models [0] recycles 0 hard 0 soft 0.87 temp 1 loss 1.77 i_con 1.76 plddt 0.92 ptm 0.86 i_ptm 0.82
# 105 models [0] recycles 0 hard 0 soft 0.88 temp 1 loss 1.74 i_con 1.73 plddt 0.92 ptm 0.86 i_ptm 0.81
# 106 models [0] recycles 0 hard 0 soft 0.88 temp 1 loss 1.74 i_con 1.73 plddt 0.92 ptm 0.86 i_ptm 0.81
# 107 models [0] recycles 0 hard 0 soft 0.89 temp 1 loss 1.76 i_con 1.76 plddt 0.92 ptm 0.86 i_ptm 0.81
# 108 models [0] recycles 0 hard 0 soft 0.90 temp 1 loss 1.77 i_con 1.76 plddt 0.91 ptm 0.86 i_ptm 0.81
# 109 models [0] recycles 0 hard 0 soft 0.91 temp 1 loss 1.81 i_con 1.80 plddt 0.91 ptm 0.85 i_ptm 0.81
# 110 models [1] recycles 0 hard 0 soft 0.92 temp 1 loss 1.48 i_con 1.48 plddt 0.95 ptm 0.89 i_ptm 0.86
# 111 models [1] recycles 0 hard 0 soft 0.93 temp 1 loss 1.56 i_con 1.55 plddt 0.94 ptm 0.89 i_ptm 0.86
# 112 models [0] recycles 0 hard 0 soft 0.93 temp 1 loss 1.65 i_con 1.64 plddt 0.93 ptm 0.86 i_ptm 0.83
# 113 models [0] recycles 0 hard 0 soft 0.94 temp 1 loss 1.80 i_con 1.79 plddt 0.91 ptm 0.85 i_ptm 0.80
# 114 models [1] recycles 0 hard 0 soft 0.95 temp 1 loss 1.56 i_con 1.55 plddt 0.94 ptm 0.88 i_ptm 0.85
# 115 models [0] recycles 0 hard 0 soft 0.96 temp 1 loss 1.93 i_con 1.92 plddt 0.89 ptm 0.85 i_ptm 0.78
# 116 models [0] recycles 0 hard 0 soft 0.97 temp 1 loss 1.88 i_con 1.87 plddt 0.90 ptm 0.85 i_ptm 0.79
# 117 models [0] recycles 0 hard 0 soft 0.97 temp 1 loss 1.85 i_con 1.84 plddt 0.90 ptm 0.86 i_ptm 0.80
# 118 models [0] recycles 0 hard 0 soft 0.98 temp 1 loss 1.81 i_con 1.80 plddt 0.90 ptm 0.86 i_ptm 0.81
# 119 models [1] recycles 0 hard 0 soft 0.99 temp 1 loss 1.56 i_con 1.55 plddt 0.94 ptm 0.88 i_ptm 0.85
# 120 models [1] recycles 0 hard 0 soft 1 temp 1 loss 1.63 i_con 1.62 plddt 0.93 ptm 0.88 i_ptm 0.84
# Running semigreedy optimization...

# %%
#@title display hallucinated protein {run: "auto"}
color = "pLDDT" #@param ["chain", "pLDDT", "rainbow"]
show_sidechains = False #@param {type:"boolean"}
show_mainchains = False #@param {type:"boolean"}
color_HP = False #@param {type:"boolean"}
animate = True #@param {type:"boolean"}
model.plot_pdb(show_sidechains=show_sidechains,
               show_mainchains=show_mainchains,
               color=color, color_HP=color_HP, animate=animate)

# %%
HTML(model.animate(dpi=100))

# %%
model.save_pdb(f"{model.protocol}.pdb")
model.get_seqs()

# %%
#@markdown ### Amino acid probabilties
import plotly.express as px
alphabet = "ACDEFGHIKLMNPQRSTVWY"
if "pssm" in dir() and pssm is not None:
  fig = px.imshow(pssm.mean(0).T,
                  labels=dict(x="positions", y="amino acids", color="probability"),
                  y=residue_constants.restypes,
                  zmin=0,
                  zmax=1,
                  template="simple_white",
                )
  fig.update_xaxes(side="top")
  fig.show()

# %%
# log
model._tmp["best"]["aux"]["log"]
